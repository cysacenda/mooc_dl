# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, \
    precision_recall_curve, average_precision_score
from sklearn.metrics import confusion_matrix
from funcsigs import signature
import pandas as pd
import numpy as np
from scipy import stats
import pickle

from sklearn.metrics import classification_report

pd.options.mode.chained_assignment = None  # default='warn'

def show_nan_count_per_column(df):
    null_columns = df.columns[df.isnull().any()]
    return df[null_columns].isnull().sum()


def get_value_count(y_):
    y_ = pd.Series(y_)
    true_count = 1  # to avoid divide by 0 - approx
    false_count = 0

    count = y_.value_counts()
    if True in count:
        true_count = count[True]
    if False in count:
        false_count = count[False]
    return true_count, false_count


def show_model_accuracy(algo_name, model, pX_test, py_test, pX_columns, do_roc_curve=False,
                        do_precision_recall_curve=False, do_features_importance=False,
                        do_precision_recall_vs_treshold=False, threshold=0.5, nb_features_imp=20):
    from matplotlib import pyplot as plt
    
    predicted_proba = model.predict(pX_test)    
    predicted = (y_pred > threshold)
    # keep probabilities for the positive outcome only
    probs = predicted_proba
    confusion = confusion_matrix(py_test, predicted)

    # Infos
    print('----------------------------------------------------------')
    print('Results for algorithm : ' + algo_name)
    print('----------------------------------------------------------\n')
    print('Confusion Matrix :\n', confusion)
    print('[[TN, FP]')
    print('[FN, TP]]')
    print('Accuracy: {:.2f}'.format(accuracy_score(py_test, predicted)))
    # print('Precision: {:.2f}'.format(precision_score(py_test, predicted)))
    # print('Recall: {:.2f}'.format(recall_score(py_test, predicted)))
    # print('F1: {:.2f}'.format(f1_score(py_test, predicted)))
    # print('AUC: {:.2f}'.format(roc_auc))
    # print('----------------------------------------------------------\n')
    print('\n\nOther Metrics :\n')
    print(classification_report(py_test, predicted, target_names=['False', 'True']))
    print('----------------------------------------------------------\n')

    # Plot ROC curve
    if do_roc_curve:
        # predicted = model.predict(pX_test)
        # fpr, tpr, thresholds = roc_curve(py_test, predicted)
        fpr, tpr, thresholds = roc_curve(py_test, probs)
        roc_auc = auc(fpr, tpr)
        plt.title('Receiver Operating Characteristic (ROC Curve)')
        plt.plot(fpr, tpr, 'b', label='AUC = %0.2f' % roc_auc)
        plt.legend(loc='lower right')
        plt.plot([0, 1], [0, 1], 'r--')
        plt.xlim([0, 1])
        plt.ylim([0, 1])
        plt.ylabel('True Positive Rate / Sensitivity')
        plt.xlabel('False Positive Rate / 1 - Specificity')
        plt.legend(loc="lower right")
        plt.show()

    # Plot Precision / Recall curve
    if do_precision_recall_curve:
        # predict class values
        yhat = predicted
        # calculate precision-recall curve
        precision, recall, thresholds = precision_recall_curve(py_test, probs)
        # calculate F1 score
        f1 = f1_score(py_test, yhat)
        # calculate precision-recall AUC
        auc_value = auc(recall, precision)
        # calculate average precision score
        ap = average_precision_score(py_test, probs)
        print('f1=%.3f auc=%.3f ap=%.3f' % (f1, auc_value, ap))
        # plot no skill
        plt.plot([0, 1], [0.5, 0.5], label='Treshold 0.5', linestyle='--')
        label = 'Treshold ' + str(threshold)
        plt.plot([0, 1], [threshold, threshold], label=label, linestyle='--')
        # plot the roc curve for the model
        # plt.plot(recall, precision, marker='.')
        plt.step(recall, precision, color='b', alpha=0.2,
                 where='post')
        # In matplotlib < 1.5, plt.fill_between does not have a 'step' argument
        step_kwargs = ({'step': 'post'}
                       if 'step' in signature(plt.fill_between).parameters
                       else {})
        plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)
        plt.title('Precision-Recall curve')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.legend(loc="lower right")
        # show the plot
        plt.show()

    if do_precision_recall_vs_treshold:
        precisions, recalls, thresholds = precision_recall_curve(py_test, probs)
        plt.plot(thresholds, precisions[:-1], "b--", label="Precision")
        plt.plot(thresholds, recalls[:-1], "g-", label="Recall")
        plt.xlabel("Threshold")
        plt.legend(loc="upper left")
        plt.ylim([0, 1])
        plt.show()

    # View a list of the features and their importance scores
    if do_features_importance:
        feat_importances = pd.Series(model.feature_importances_, index=pX_columns)
        if nb_features_imp > 20:
            plt.figure(figsize=(20, 20))
        feat_importances.nlargest(nb_features_imp).plot(kind='barh')
        plt.show()


def get_useless_features(model, index, threshold=0.002):
    s = pd.Series(model.feature_importances_, index=index)
    return s[s <= threshold].index.values


# Serialization
def save_obj(obj, name):
    with open('obj/' + name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)


def load_obj(name):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
onehotencoder = ColumnTransformer([('one_hot_encoder', OneHotEncoder(),[1])], remainder = 'passthrough')
X = onehotencoder.fit_transform(X)
X = X[:, 1:]

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))

# Adding dropout to avoir overfitting - start with 0.1
classifier.add(Dropout(rate = 0.1))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dropout(rate = 0.1))

# Adding the output layer - sigmoid to obtain a probability
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Train on 8000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 2s 216us/sample - loss: 0.4927 - accuracy: 0.7961
# Epoch 2/100
# 8000/8000 [==============================] - 1s 128us/sample - loss: 0.4384 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 1s 126us/sample - loss: 0.4356 - accuracy: 0.7960
# Epoch 4/100
# 8000/8000 [==============================] - 1s 118us/sample - loss: 0.4337 - accuracy: 0.7960
# Epoch 5/100
# 8000/8000 [==============================] - 1s 107us/sample - loss: 0.4325 - accuracy: 0.7960
# Epoch 6/100
# 8000/8000 [==============================] - 1s 109us/sample - loss: 0.4273 - accuracy: 0.7960 - loss: 0.4259 - accuracy: 0.
# Epoch 7/100
# 8000/8000 [==============================] - 1s 127us/sample - loss: 0.4313 - accuracy: 0.7960
# Epoch 8/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.4280 - accuracy: 0.7971
# Epoch 9/100
# 8000/8000 [==============================] - 1s 128us/sample - loss: 0.4293 - accuracy: 0.8133
# Epoch 10/100
# 8000/8000 [==============================] - 1s 126us/sample - loss: 0.4275 - accuracy: 0.8204
# Epoch 11/100
# 8000/8000 [==============================] - 1s 133us/sample - loss: 0.4308 - accuracy: 0.8209
# Epoch 12/100
# 8000/8000 [==============================] - 1s 131us/sample - loss: 0.4280 - accuracy: 0.8240
# Epoch 13/100
# 8000/8000 [==============================] - 1s 125us/sample - loss: 0.4275 - accuracy: 0.8223
# Epoch 14/100
# 8000/8000 [==============================] - 1s 146us/sample - loss: 0.4247 - accuracy: 0.8236
# Epoch 15/100
# 8000/8000 [==============================] - 1s 140us/sample - loss: 0.4268 - accuracy: 0.8240
# Epoch 16/100
# 8000/8000 [==============================] - 1s 137us/sample - loss: 0.4231 - accuracy: 0.8240
# Epoch 17/100
# 8000/8000 [==============================] - 1s 119us/sample - loss: 0.4246 - accuracy: 0.8260
# Epoch 18/100
# 8000/8000 [==============================] - 1s 119us/sample - loss: 0.4297 - accuracy: 0.8259
# Epoch 19/100
# 8000/8000 [==============================] - 1s 138us/sample - loss: 0.4279 - accuracy: 0.8257
# Epoch 20/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.4272 - accuracy: 0.8254
# Epoch 21/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.4266 - accuracy: 0.8266
# Epoch 22/100
# 8000/8000 [==============================] - 1s 111us/sample - loss: 0.4282 - accuracy: 0.8249
# Epoch 23/100
# 8000/8000 [==============================] - 1s 110us/sample - loss: 0.4249 - accuracy: 0.8298
# Epoch 24/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.4255 - accuracy: 0.8254
# Epoch 25/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.4268 - accuracy: 0.8280
# Epoch 26/100
# 8000/8000 [==============================] - 1s 117us/sample - loss: 0.4235 - accuracy: 0.8236
# Epoch 27/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.4233 - accuracy: 0.8280
# Epoch 28/100
# 8000/8000 [==============================] - 1s 119us/sample - loss: 0.4268 - accuracy: 0.8254
# Epoch 29/100
# 8000/8000 [==============================] - 1s 113us/sample - loss: 0.4252 - accuracy: 0.8285
# Epoch 30/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.4247 - accuracy: 0.8265
# Epoch 31/100
# 8000/8000 [==============================] - 1s 119us/sample - loss: 0.4256 - accuracy: 0.8290
# Epoch 32/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.4224 - accuracy: 0.8279
# Epoch 33/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.4235 - accuracy: 0.8288 - loss: 0.4185 - accuracy: 0. - ETA: 0s - loss: 0.4190 - accu
# Epoch 34/100
# 8000/8000 [==============================] - 1s 110us/sample - loss: 0.4251 - accuracy: 0.8289
# Epoch 35/100
# 8000/8000 [==============================] - 1s 114us/sample - loss: 0.4267 - accuracy: 0.8273
# Epoch 36/100
# 8000/8000 [==============================] - 1s 115us/sample - loss: 0.4250 - accuracy: 0.8273
# Epoch 37/100
# 8000/8000 [==============================] - 1s 120us/sample - loss: 0.4299 - accuracy: 0.8275
# Epoch 38/100
# 8000/8000 [==============================] - 1s 116us/sample - loss: 0.4224 - accuracy: 0.8305 - loss:
# Epoch 39/100
# 8000/8000 [==============================] - 1s 118us/sample - loss: 0.4246 - accuracy: 0.8294
# Epoch 40/100
# 8000/8000 [==============================] - 1s 111us/sample - loss: 0.4267 - accuracy: 0.8270
# Epoch 41/100
# 8000/8000 [==============================] - 1s 120us/sample - loss: 0.4235 - accuracy: 0.8285
# Epoch 42/100
# 8000/8000 [==============================] - 1s 112us/sample - loss: 0.4255 - accuracy: 0.8294
# Epoch 43/100
# 8000/8000 [==============================] - 1s 121us/sample - loss: 0.4244 - accuracy: 0.8284
# Epoch 44/100
# 8000/8000 [==============================] - 1s 111us/sample - loss: 0.4216 - accuracy: 0.8289
# Epoch 45/100
# 8000/8000 [==============================] - 1s 119us/sample - loss: 0.4257 - accuracy: 0.8304
# Epoch 46/100
# 8000/8000 [==============================] - 1s 120us/sample - loss: 0.4268 - accuracy: 0.8303
# Epoch 47/100
# 8000/8000 [==============================] - 1s 126us/sample - loss: 0.4217 - accuracy: 0.8294
# Epoch 48/100
# 8000/8000 [==============================] - 1s 140us/sample - loss: 0.4243 - accuracy: 0.8285
# Epoch 49/100
# 8000/8000 [==============================] - 1s 139us/sample - loss: 0.4244 - accuracy: 0.8289
# Epoch 50/100
# 8000/8000 [==============================] - 1s 137us/sample - loss: 0.4250 - accuracy: 0.8274
# Epoch 51/100
# 8000/8000 [==============================] - 1s 138us/sample - loss: 0.4221 - accuracy: 0.8288
# Epoch 52/100
# 8000/8000 [==============================] - 1s 122us/sample - loss: 0.4253 - accuracy: 0.8292
# Epoch 53/100
# 8000/8000 [==============================] - 1s 125us/sample - loss: 0.4255 - accuracy: 0.8292
# Epoch 54/100
# 8000/8000 [==============================] - 1s 127us/sample - loss: 0.4229 - accuracy: 0.8292
# Epoch 55/100
# 8000/8000 [==============================] - 1s 125us/sample - loss: 0.4230 - accuracy: 0.8278 - l
# Epoch 56/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4242 - accuracy: 0.8296
# Epoch 57/100
# 8000/8000 [==============================] - 1s 122us/sample - loss: 0.4215 - accuracy: 0.8313
# Epoch 58/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4237 - accuracy: 0.8265
# Epoch 59/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4255 - accuracy: 0.8280
# Epoch 60/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4231 - accuracy: 0.8304
# Epoch 61/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4257 - accuracy: 0.8282
# Epoch 62/100
# 8000/8000 [==============================] - 1s 122us/sample - loss: 0.4252 - accuracy: 0.8285 - loss: 0.4
# Epoch 63/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4244 - accuracy: 0.8276
# Epoch 64/100
# 8000/8000 [==============================] - 1s 130us/sample - loss: 0.4235 - accuracy: 0.8289 - loss: 0.4384 - ac
# Epoch 65/100
# 8000/8000 [==============================] - 1s 132us/sample - loss: 0.4262 - accuracy: 0.8273
# Epoch 66/100
# 8000/8000 [==============================] - 1s 124us/sample - loss: 0.4250 - accuracy: 0.8263
# Epoch 67/100
# 8000/8000 [==============================] - ETA: 0s - loss: 0.4218 - accuracy: 0.82 - 1s 124us/sample - loss: 0.4232 - accuracy: 0.8285
# Epoch 68/100
# 8000/8000 [==============================] - 1s 122us/sample - loss: 0.4275 - accuracy: 0.8295
# Epoch 69/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4234 - accuracy: 0.8309
# Epoch 70/100
# 8000/8000 [==============================] - 1s 122us/sample - loss: 0.4235 - accuracy: 0.8285
# Epoch 71/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4261 - accuracy: 0.8303
# Epoch 72/100
# 8000/8000 [==============================] - 1s 137us/sample - loss: 0.4251 - accuracy: 0.8295
# Epoch 73/100
# 8000/8000 [==============================] - 1s 141us/sample - loss: 0.4253 - accuracy: 0.8286
# Epoch 74/100
# 8000/8000 [==============================] - 1s 139us/sample - loss: 0.4269 - accuracy: 0.8307
# Epoch 75/100
# 8000/8000 [==============================] - 1s 148us/sample - loss: 0.4256 - accuracy: 0.8306
# Epoch 76/100
# 8000/8000 [==============================] - 1s 119us/sample - loss: 0.4258 - accuracy: 0.8303 - loss: 0.4294 -
# Epoch 77/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4233 - accuracy: 0.8298
# Epoch 78/100
# 8000/8000 [==============================] - 1s 117us/sample - loss: 0.4257 - accuracy: 0.8310
# Epoch 79/100
# 8000/8000 [==============================] - 1s 122us/sample - loss: 0.4246 - accuracy: 0.8279
# Epoch 80/100
# 8000/8000 [==============================] - 1s 120us/sample - loss: 0.4206 - accuracy: 0.8301
# Epoch 81/100
# 8000/8000 [==============================] - 1s 127us/sample - loss: 0.4219 - accuracy: 0.8301
# Epoch 82/100
# 8000/8000 [==============================] - 1s 118us/sample - loss: 0.4256 - accuracy: 0.8321
# Epoch 83/100
# 8000/8000 [==============================] - 1s 121us/sample - loss: 0.4224 - accuracy: 0.8305
# Epoch 84/100
# 8000/8000 [==============================] - 1s 120us/sample - loss: 0.4230 - accuracy: 0.8332
# Epoch 85/100
# 8000/8000 [==============================] - ETA: 0s - loss: 0.4221 - accuracy: 0.83 - 1s 121us/sample - loss: 0.4239 - accuracy: 0.8306
# Epoch 86/100
# 8000/8000 [==============================] - 1s 130us/sample - loss: 0.4223 - accuracy: 0.8282
# Epoch 87/100
# 8000/8000 [==============================] - 1s 129us/sample - loss: 0.4224 - accuracy: 0.8310
# Epoch 88/100
# 8000/8000 [==============================] - 1s 125us/sample - loss: 0.4238 - accuracy: 0.8309
# Epoch 89/100
# 8000/8000 [==============================] - 1s 120us/sample - loss: 0.4255 - accuracy: 0.8303
# Epoch 90/100
# 8000/8000 [==============================] - 1s 121us/sample - loss: 0.4233 - accuracy: 0.8290
# Epoch 91/100
# 8000/8000 [==============================] - 1s 124us/sample - loss: 0.4216 - accuracy: 0.8306
# Epoch 92/100
# 8000/8000 [==============================] - 1s 120us/sample - loss: 0.4227 - accuracy: 0.8309
# Epoch 93/100
# 8000/8000 [==============================] - 1s 120us/sample - loss: 0.4248 - accuracy: 0.8309
# Epoch 94/100
# 8000/8000 [==============================] - 1s 121us/sample - loss: 0.4249 - accuracy: 0.8286 - loss: 0 - ETA: 0s - loss: 0.4218 - accura
# Epoch 95/100
# 8000/8000 [==============================] - 1s 123us/sample - loss: 0.4228 - accuracy: 0.8278
# Epoch 96/100
# 8000/8000 [==============================] - 1s 122us/sample - loss: 0.4236 - accuracy: 0.8309 - loss: 0.4192 - accu
# Epoch 97/100
# 8000/8000 [==============================] - 1s 137us/sample - loss: 0.4207 - accuracy: 0.8290
# Epoch 98/100
# 8000/8000 [==============================] - 1s 122us/sample - loss: 0.4202 - accuracy: 0.8292
# Epoch 99/100
# 8000/8000 [==============================] - 1s 127us/sample - loss: 0.4230 - accuracy: 0.8309 - loss: 0.4242 - accuracy
# Epoch 100/100
# 8000/8000 [==============================] - 1s 138us/sample - loss: 0.4230 - accuracy: 0.8325

# %%
# Part 3 - Making predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.50)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
show_model_accuracy('test_csa', classifier, X_test, y_test, None, do_roc_curve=True,
                        do_precision_recall_curve=True, do_features_importance=False,
                        do_precision_recall_vs_treshold=True, threshold=0.5)
# Out:
# ----------------------------------------------------------
# Results for algorithm : test_csa
# ----------------------------------------------------------
#
# Confusion Matrix :
#  [[1563   32]
#  [ 287  118]]
# [[TN, FP]
# [FN, TP]]
# Accuracy: 0.84
#
#
# Other Metrics :
#
#               precision    recall  f1-score   support
#
#        False       0.84      0.98      0.91      1595
#         True       0.79      0.29      0.43       405
#
#     accuracy                           0.84      2000
#    macro avg       0.82      0.64      0.67      2000
# weighted avg       0.83      0.84      0.81      2000
#
# ----------------------------------------------------------
# f1=0.425 auc=0.599 ap=0.583

# %%
# Evaluating the ANN
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier, batch_size = 10, epochs = 100)
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10, n_jobs = -1)
mean = accuracies.mean()
variance = accuracies.std()

# Improving the ANN
# Dropout Regularization to reduce overfitting if needed

# Tuning the ANN
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier)
parameters = {'batch_size': [25, 32],
              'epochs': [100, 500],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10)
grid_search = grid_search.fit(X_train, y_train)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
# Out:
# Train on 7200 samples
# Epoch 1/100
# 7200/7200 [==============================] - 3s 448us/sample - loss: 0.5551 - accuracy: 0.7968
# Epoch 2/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4338 - accuracy: 0.7971
# Epoch 3/100
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4281 - accuracy: 0.7971
# Epoch 4/100
# 7200/7200 [==============================] - 1s 100us/sample - loss: 0.4247 - accuracy: 0.7971
# Epoch 5/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4218 - accuracy: 0.7971
# Epoch 6/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4195 - accuracy: 0.7999
# Epoch 7/100
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.4178 - accuracy: 0.8206
# Epoch 8/100
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.4168 - accuracy: 0.8231
# Epoch 9/100
# 7200/7200 [==============================] - 1s 99us/sample - loss: 0.4154 - accuracy: 0.8260
# Epoch 10/100
# 7200/7200 [==============================] - 1s 101us/sample - loss: 0.4141 - accuracy: 0.8282
# Epoch 11/100
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.4130 - accuracy: 0.8290
# Epoch 12/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.4123 - accuracy: 0.8308
# Epoch 13/100
# 7200/7200 [==============================] - 1s 102us/sample - loss: 0.4113 - accuracy: 0.8311
# Epoch 14/100
# 7200/7200 [==============================] - 1s 99us/sample - loss: 0.4110 - accuracy: 0.8324
# Epoch 15/100
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.4101 - accuracy: 0.8329
# Epoch 16/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.4095 - accuracy: 0.8349
# Epoch 17/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4089 - accuracy: 0.8336
# Epoch 18/100
# 7200/7200 [==============================] - 1s 99us/sample - loss: 0.4082 - accuracy: 0.8347
# Epoch 19/100
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.4078 - accuracy: 0.8350
# Epoch 20/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.4076 - accuracy: 0.8354
# Epoch 21/100
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4072 - accuracy: 0.8353
# Epoch 22/100
# 7200/7200 [==============================] - 1s 111us/sample - loss: 0.4067 - accuracy: 0.8353
# Epoch 23/100
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4059 - accuracy: 0.8356
# Epoch 24/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4061 - accuracy: 0.8347
# Epoch 25/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4056 - accuracy: 0.8349
# Epoch 26/100
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4057 - accuracy: 0.8354
# Epoch 27/100
# 7200/7200 [==============================] - 1s 115us/sample - loss: 0.4053 - accuracy: 0.8353
# Epoch 28/100
# 7200/7200 [==============================] - 1s 101us/sample - loss: 0.4052 - accuracy: 0.8357
# Epoch 29/100
# 7200/7200 [==============================] - 1s 84us/sample - loss: 0.4049 - accuracy: 0.8350
# Epoch 30/100
# 7200/7200 [==============================] - 0s 46us/sample - loss: 0.4047 - accuracy: 0.8346
# Epoch 31/100
# 7200/7200 [==============================] - 0s 46us/sample - loss: 0.4044 - accuracy: 0.8351
# Epoch 32/100
# 7200/7200 [==============================] - 0s 60us/sample - loss: 0.4044 - accuracy: 0.8336
# Epoch 33/100
# 7200/7200 [==============================] - 0s 46us/sample - loss: 0.4042 - accuracy: 0.8351s - loss: 0.4056 - accuracy: 0.
# Epoch 34/100
# 7200/7200 [==============================] - 1s 73us/sample - loss: 0.4041 - accuracy: 0.8353
# Epoch 35/100
# 7200/7200 [==============================] - 0s 67us/sample - loss: 0.4044 - accuracy: 0.8347
# Epoch 36/100
# 7200/7200 [==============================] - 0s 68us/sample - loss: 0.4040 - accuracy: 0.8358
# Epoch 37/100
# 7200/7200 [==============================] - 0s 68us/sample - loss: 0.4037 - accuracy: 0.8351
# Epoch 38/100
# 7200/7200 [==============================] - 1s 89us/sample - loss: 0.4036 - accuracy: 0.8354
# Epoch 39/100
# 7200/7200 [==============================] - 0s 65us/sample - loss: 0.4033 - accuracy: 0.8350
# Epoch 40/100
# 7200/7200 [==============================] - 0s 60us/sample - loss: 0.4031 - accuracy: 0.8363
# Epoch 41/100
# 7200/7200 [==============================] - 0s 45us/sample - loss: 0.4032 - accuracy: 0.8349
# Epoch 42/100
# 7200/7200 [==============================] - 0s 45us/sample - loss: 0.4030 - accuracy: 0.8339
# Epoch 43/100
# 7200/7200 [==============================] - 0s 45us/sample - loss: 0.4030 - accuracy: 0.8350
# Epoch 44/100
# 7200/7200 [==============================] - 0s 46us/sample - loss: 0.4029 - accuracy: 0.8357
# Epoch 45/100
# 7200/7200 [==============================] - 0s 45us/sample - loss: 0.4025 - accuracy: 0.8349
# Epoch 46/100
# 7200/7200 [==============================] - 0s 57us/sample - loss: 0.4024 - accuracy: 0.8351
# Epoch 47/100
# 7200/7200 [==============================] - 1s 97us/sample - loss: 0.4024 - accuracy: 0.8347
# Epoch 48/100
# 7200/7200 [==============================] - 1s 100us/sample - loss: 0.4025 - accuracy: 0.8347
# Epoch 49/100
# 7200/7200 [==============================] - 1s 102us/sample - loss: 0.4023 - accuracy: 0.8343
# Epoch 50/100
# 7200/7200 [==============================] - 0s 63us/sample - loss: 0.4021 - accuracy: 0.8354
# Epoch 51/100
# 7200/7200 [==============================] - 0s 55us/sample - loss: 0.4022 - accuracy: 0.8363
# Epoch 52/100
# 7200/7200 [==============================] - 0s 60us/sample - loss: 0.4022 - accuracy: 0.8353
# Epoch 53/100
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.4019 - accuracy: 0.8346
# Epoch 54/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4019 - accuracy: 0.8354
# Epoch 55/100
# 7200/7200 [==============================] - 1s 100us/sample - loss: 0.4016 - accuracy: 0.8336
# Epoch 56/100
# 7200/7200 [==============================] - 1s 98us/sample - loss: 0.4015 - accuracy: 0.8356
# Epoch 57/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4014 - accuracy: 0.8357
# Epoch 58/100
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4016 - accuracy: 0.8342
# Epoch 59/100
# 7200/7200 [==============================] - 1s 97us/sample - loss: 0.4015 - accuracy: 0.8353
# Epoch 60/100
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4019 - accuracy: 0.8333
# Epoch 61/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4014 - accuracy: 0.8335
# Epoch 62/100
# 7200/7200 [==============================] - 1s 76us/sample - loss: 0.4018 - accuracy: 0.8343
# Epoch 63/100
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.4013 - accuracy: 0.8350
# Epoch 64/100
# 7200/7200 [==============================] - 1s 99us/sample - loss: 0.4009 - accuracy: 0.8338
# Epoch 65/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4013 - accuracy: 0.8344
# Epoch 66/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4013 - accuracy: 0.8339
# Epoch 67/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4012 - accuracy: 0.8350
# Epoch 68/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4013 - accuracy: 0.8344
# Epoch 69/100
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4010 - accuracy: 0.8349
# Epoch 70/100
# 7200/7200 [==============================] - 1s 102us/sample - loss: 0.4011 - accuracy: 0.8346
# Epoch 71/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4010 - accuracy: 0.8338
# Epoch 72/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4005 - accuracy: 0.8346
# Epoch 73/100
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.4011 - accuracy: 0.8333
# Epoch 74/100
# 7200/7200 [==============================] - 1s 115us/sample - loss: 0.4009 - accuracy: 0.8346
# Epoch 75/100
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4003 - accuracy: 0.8339
# Epoch 76/100
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4007 - accuracy: 0.8331
# Epoch 77/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4004 - accuracy: 0.8340
# Epoch 78/100
# 7200/7200 [==============================] - 0s 65us/sample - loss: 0.4009 - accuracy: 0.8339
# Epoch 79/100
# 7200/7200 [==============================] - 1s 92us/sample - loss: 0.4008 - accuracy: 0.8339
# Epoch 80/100
# 7200/7200 [==============================] - 1s 94us/sample - loss: 0.4002 - accuracy: 0.8349
# Epoch 81/100
# 7200/7200 [==============================] - 1s 90us/sample - loss: 0.4008 - accuracy: 0.8339
# Epoch 82/100
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.4006 - accuracy: 0.8353
# Epoch 83/100
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4005 - accuracy: 0.8332
# Epoch 84/100
# 7200/7200 [==============================] - 1s 110us/sample - loss: 0.4005 - accuracy: 0.8346
# Epoch 85/100
# 7200/7200 [==============================] - 0s 69us/sample - loss: 0.4002 - accuracy: 0.8336
# Epoch 86/100
# 7200/7200 [==============================] - 1s 74us/sample - loss: 0.4001 - accuracy: 0.8343
# Epoch 87/100
# 7200/7200 [==============================] - 1s 111us/sample - loss: 0.4003 - accuracy: 0.8346
# Epoch 88/100
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4009 - accuracy: 0.8356
# Epoch 89/100
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.4000 - accuracy: 0.8349
# Epoch 90/100
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.4005 - accuracy: 0.8356
# Epoch 91/100
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4001 - accuracy: 0.8340
# Epoch 92/100
# 7200/7200 [==============================] - 1s 102us/sample - loss: 0.4000 - accuracy: 0.8340
# Epoch 93/100
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.3998 - accuracy: 0.8332
# Epoch 94/100
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4000 - accuracy: 0.8351
# Epoch 95/100
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.3999 - accuracy: 0.8347
# Epoch 96/100
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.4002 - accuracy: 0.8340
# Epoch 97/100
# 7200/7200 [==============================] - 1s 102us/sample - loss: 0.4001 - accuracy: 0.8331
# Epoch 98/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.4000 - accuracy: 0.8336
# Epoch 99/100
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.3998 - accuracy: 0.8342
# Epoch 100/100
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4001 - accuracy: 0.8339
# Train on 7200 samples
# Epoch 1/100
# 7200/7200 [==============================] - 2s 232us/sample - loss: 0.5828 - accuracy: 0.7939
# Epoch 2/100
# 7200/7200 [==============================] - 1s 101us/sample - loss: 0.4364 - accuracy: 0.7967
# Epoch 3/100
# 7200/7200 [==============================] - 1s 95us/sample - loss: 0.4300 - accuracy: 0.7967
# Epoch 4/100
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4273 - accuracy: 0.7967
# Epoch 5/100
# 7200/7200 [==============================] - 1s 101us/sample - loss: 0.4253 - accuracy: 0.7967
# Epoch 6/100
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4229 - accuracy: 0.7967
# Epoch 7/100
# 7200/7200 [==============================] - 1s 100us/sample - loss: 0.4208 - accuracy: 0.7967
# Epoch 8/100
# 7200/7200 [==============================] - 1s 80us/sample - loss: 0.4186 - accuracy: 0.8131
# Epoch 9/100
# 7200/7200 [==============================] - 1s 92us/sample - loss: 0.4170 - accuracy: 0.8235
# Epoch 10/100
# 7200/7200 [==============================] - 0s 59us/sample - loss: 0.4157 - accuracy: 0.8256
# Epoch 11/100
# 7200/7200 [==============================] - 0s 67us/sample - loss: 0.4147 - accuracy: 0.8256
# Epoch 12/100
# 7200/7200 [==============================] - 0s 66us/sample - loss: 0.4139 - accuracy: 0.8286
# Epoch 13/100
# 7200/7200 [==============================] - 0s 67us/sample - loss: 0.4128 - accuracy: 0.8285
# Epoch 14/100
# 7200/7200 [==============================] - 0s 62us/sample - loss: 0.4116 - accuracy: 0.8308
# Epoch 15/100
# 7200/7200 [==============================] - 0s 54us/sample - loss: 0.4113 - accuracy: 0.8317
# Epoch 16/100
# 7200/7200 [==============================] - 0s 45us/sample - loss: 0.4106 - accuracy: 0.8311
# Epoch 17/100
# 7200/7200 [==============================] - 0s 50us/sample - loss: 0.4101 - accuracy: 0.8315
# Epoch 18/100
# 7200/7200 [==============================] - 0s 62us/sample - loss: 0.4094 - accuracy: 0.8324
# Epoch 19/100
# 7200/7200 [==============================] - 0s 62us/sample - loss: 0.4088 - accuracy: 0.8321
# Epoch 20/100
# 7200/7200 [==============================] - 1s 77us/sample - loss: 0.4084 - accuracy: 0.8314
# Epoch 21/100
# 7200/7200 [==============================] - 1s 85us/sample - loss: 0.4081 - accuracy: 0.8315
# Epoch 22/100
# 7200/7200 [==============================] - 1s 77us/sample - loss: 0.4077 - accuracy: 0.8317
# Epoch 23/100
# 7200/7200 [==============================] - 1s 84us/sample - loss: 0.4073 - accuracy: 0.8336
# Epoch 24/100
# 7200/7200 [==============================] - 1s 81us/sample - loss: 0.4067 - accuracy: 0.8339
# Epoch 25/100
# 7200/7200 [==============================] - 1s 80us/sample - loss: 0.4070 - accuracy: 0.8331
# Epoch 26/100
# 7200/7200 [==============================] - 1s 79us/sample - loss: 0.4065 - accuracy: 0.8328
# Epoch 27/100
# 7200/7200 [==============================] - 1s 81us/sample - loss: 0.4060 - accuracy: 0.8332
# Epoch 28/100
# 7200/7200 [==============================] - 1s 133us/sample - loss: 0.4059 - accuracy: 0.8331
# Epoch 29/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.4054 - accuracy: 0.8336
# Epoch 30/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.4054 - accuracy: 0.8350
# Epoch 31/100
# 7200/7200 [==============================] - 1s 133us/sample - loss: 0.4051 - accuracy: 0.8335
# Epoch 32/100
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.4049 - accuracy: 0.8342
# Epoch 33/100
# 7200/7200 [==============================] - ETA: 0s - loss: 0.4057 - accuracy: 0.83 - 1s 134us/sample - loss: 0.4048 - accuracy: 0.8354
# Epoch 34/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.4043 - accuracy: 0.8342
# Epoch 35/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.4042 - accuracy: 0.8344
# Epoch 36/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4041 - accuracy: 0.8328
# Epoch 37/100
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4038 - accuracy: 0.8349
# Epoch 38/100
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.4035 - accuracy: 0.8368
# Epoch 39/100
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4033 - accuracy: 0.8343
# Epoch 40/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4031 - accuracy: 0.8354
# Epoch 41/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.4032 - accuracy: 0.8363
# Epoch 42/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4029 - accuracy: 0.8353
# Epoch 43/100
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4028 - accuracy: 0.8339
# Epoch 44/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.4024 - accuracy: 0.8346
# Epoch 45/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4022 - accuracy: 0.8356
# Epoch 46/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.4025 - accuracy: 0.8344
# Epoch 47/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4020 - accuracy: 0.8340
# Epoch 48/100
# 7200/7200 [==============================] - 1s 111us/sample - loss: 0.4022 - accuracy: 0.8351
# Epoch 49/100
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4017 - accuracy: 0.8347
# Epoch 50/100
# 7200/7200 [==============================] - 1s 102us/sample - loss: 0.4019 - accuracy: 0.8347
# Epoch 51/100
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4015 - accuracy: 0.8340
# Epoch 52/100
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4012 - accuracy: 0.8363
# Epoch 53/100
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4013 - accuracy: 0.8353
# Epoch 54/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.4017 - accuracy: 0.8354
# Epoch 55/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.4010 - accuracy: 0.8363
# Epoch 56/100
# 7200/7200 [==============================] - 1s 115us/sample - loss: 0.4011 - accuracy: 0.8351
# Epoch 57/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4010 - accuracy: 0.8349
# Epoch 58/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.4006 - accuracy: 0.8351
# Epoch 59/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.4008 - accuracy: 0.8351
# Epoch 60/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.4008 - accuracy: 0.8353
# Epoch 61/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.4007 - accuracy: 0.8351
# Epoch 62/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.4005 - accuracy: 0.8361
# Epoch 63/100
# 7200/7200 [==============================] - 1s 135us/sample - loss: 0.4003 - accuracy: 0.8364
# Epoch 64/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.4003 - accuracy: 0.8363
# Epoch 65/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.4007 - accuracy: 0.8346
# Epoch 66/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.4002 - accuracy: 0.8357
# Epoch 67/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3999 - accuracy: 0.8364
# Epoch 68/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.3999 - accuracy: 0.8357
# Epoch 69/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.4001 - accuracy: 0.8351
# Epoch 70/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.3999 - accuracy: 0.8363
# Epoch 71/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.4001 - accuracy: 0.8363
# Epoch 72/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.4000 - accuracy: 0.8372
# Epoch 73/100
# 7200/7200 [==============================] - 1s 134us/sample - loss: 0.3996 - accuracy: 0.8358
# Epoch 74/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3997 - accuracy: 0.8357
# Epoch 75/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.3995 - accuracy: 0.8364
# Epoch 76/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.3995 - accuracy: 0.8376
# Epoch 77/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3993 - accuracy: 0.8357
# Epoch 78/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.3996 - accuracy: 0.8357
# Epoch 79/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.4000 - accuracy: 0.8360
# Epoch 80/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3995 - accuracy: 0.8357
# Epoch 81/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3996 - accuracy: 0.8363
# Epoch 82/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3997 - accuracy: 0.8372
# Epoch 83/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3992 - accuracy: 0.8361
# Epoch 84/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3995 - accuracy: 0.8365
# Epoch 85/100
# 7200/7200 [==============================] - 1s 115us/sample - loss: 0.3995 - accuracy: 0.8358
# Epoch 86/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3993 - accuracy: 0.8367
# Epoch 87/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.3993 - accuracy: 0.8365
# Epoch 88/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.3992 - accuracy: 0.8356
# Epoch 89/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3992 - accuracy: 0.8365
# Epoch 90/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.3997 - accuracy: 0.8363
# Epoch 91/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3991 - accuracy: 0.8361
# Epoch 92/100
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.3992 - accuracy: 0.8364
# Epoch 93/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.3992 - accuracy: 0.8356 - loss: 0.3
# Epoch 94/100
# 7200/7200 [==============================] - 1s 134us/sample - loss: 0.3992 - accuracy: 0.8376
# Epoch 95/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3989 - accuracy: 0.8369
# Epoch 96/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3991 - accuracy: 0.8365
# Epoch 97/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3991 - accuracy: 0.8354
# Epoch 98/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.3993 - accuracy: 0.8371
# Epoch 99/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3990 - accuracy: 0.8350
# Epoch 100/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3991 - accuracy: 0.8368
# Train on 7200 samples
# Epoch 1/100
# 7200/7200 [==============================] - 2s 289us/sample - loss: 0.6000 - accuracy: 0.7943
# Epoch 2/100
# 7200/7200 [==============================] - 1s 136us/sample - loss: 0.4435 - accuracy: 0.7956
# Epoch 3/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4315 - accuracy: 0.7956
# Epoch 4/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4269 - accuracy: 0.7956
# Epoch 5/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.4234 - accuracy: 0.7956 - l
# Epoch 6/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.4198 - accuracy: 0.8215
# Epoch 7/100
# 7200/7200 [==============================] - 1s 101us/sample - loss: 0.4160 - accuracy: 0.8275
# Epoch 8/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.4127 - accuracy: 0.8274
# Epoch 9/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4105 - accuracy: 0.8315
# Epoch 10/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.4081 - accuracy: 0.8333
# Epoch 11/100
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.4059 - accuracy: 0.8335
# Epoch 12/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.4041 - accuracy: 0.8339
# Epoch 13/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.4026 - accuracy: 0.8343
# Epoch 14/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4017 - accuracy: 0.8358
# Epoch 15/100
# 7200/7200 [==============================] - 1s 115us/sample - loss: 0.4001 - accuracy: 0.8350
# Epoch 16/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.3986 - accuracy: 0.8354
# Epoch 17/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.3972 - accuracy: 0.8363
# Epoch 18/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.3954 - accuracy: 0.8379
# Epoch 19/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.3936 - accuracy: 0.8386
# Epoch 20/100
# 7200/7200 [==============================] - 1s 111us/sample - loss: 0.3913 - accuracy: 0.8372
# Epoch 21/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.3890 - accuracy: 0.8397
# Epoch 22/100
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.3867 - accuracy: 0.8431
# Epoch 23/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.3849 - accuracy: 0.8411
# Epoch 24/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3835 - accuracy: 0.8419
# Epoch 25/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.3818 - accuracy: 0.8413
# Epoch 26/100
# 7200/7200 [==============================] - 1s 110us/sample - loss: 0.3802 - accuracy: 0.8435
# Epoch 27/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.3794 - accuracy: 0.8426
# Epoch 28/100
# 7200/7200 [==============================] - 1s 110us/sample - loss: 0.3782 - accuracy: 0.8428
# Epoch 29/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3768 - accuracy: 0.8421
# Epoch 30/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.3759 - accuracy: 0.8425
# Epoch 31/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.3751 - accuracy: 0.8436
# Epoch 32/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3744 - accuracy: 0.8424
# Epoch 33/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.3721 - accuracy: 0.8436
# Epoch 34/100
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.3712 - accuracy: 0.8432
# Epoch 35/100
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.3697 - accuracy: 0.8447
# Epoch 36/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.3681 - accuracy: 0.8457
# Epoch 37/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3662 - accuracy: 0.8467
# Epoch 38/100
# 7200/7200 [==============================] - 1s 137us/sample - loss: 0.3647 - accuracy: 0.8478 -
# Epoch 39/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.3641 - accuracy: 0.8468
# Epoch 40/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3624 - accuracy: 0.8494
# Epoch 41/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.3602 - accuracy: 0.8532
# Epoch 42/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.3590 - accuracy: 0.8526
# Epoch 43/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3577 - accuracy: 0.8504
# Epoch 44/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.3568 - accuracy: 0.8547
# Epoch 45/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3560 - accuracy: 0.8537 - l
# Epoch 46/100
# 7200/7200 [==============================] - 1s 139us/sample - loss: 0.3543 - accuracy: 0.8558
# Epoch 47/100
# 7200/7200 [==============================] - 1s 82us/sample - loss: 0.3538 - accuracy: 0.8546
# Epoch 48/100
# 7200/7200 [==============================] - 1s 82us/sample - loss: 0.3528 - accuracy: 0.8560
# Epoch 49/100
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.3522 - accuracy: 0.8561
# Epoch 50/100
# 7200/7200 [==============================] - 1s 91us/sample - loss: 0.3509 - accuracy: 0.8572
# Epoch 51/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.3511 - accuracy: 0.8569
# Epoch 52/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.3503 - accuracy: 0.8576
# Epoch 53/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3510 - accuracy: 0.8572
# Epoch 54/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3503 - accuracy: 0.8569
# Epoch 55/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.3488 - accuracy: 0.8585
# Epoch 56/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3486 - accuracy: 0.8564
# Epoch 57/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.3482 - accuracy: 0.8582
# Epoch 58/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3475 - accuracy: 0.8582
# Epoch 59/100
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.3479 - accuracy: 0.8562
# Epoch 60/100
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.3474 - accuracy: 0.8568
# Epoch 61/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3473 - accuracy: 0.8579
# Epoch 62/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.3470 - accuracy: 0.8585
# Epoch 63/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3465 - accuracy: 0.8593
# Epoch 64/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.3454 - accuracy: 0.8565
# Epoch 65/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3463 - accuracy: 0.8603 - loss: 0.3352 - accu
# Epoch 66/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3464 - accuracy: 0.8579
# Epoch 67/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.3462 - accuracy: 0.8574
# Epoch 68/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3461 - accuracy: 0.8568
# Epoch 69/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3461 - accuracy: 0.8597
# Epoch 70/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.3454 - accuracy: 0.8590
# Epoch 71/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3455 - accuracy: 0.8592
# Epoch 72/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3448 - accuracy: 0.8586
# Epoch 73/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.3453 - accuracy: 0.8587
# Epoch 74/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.3443 - accuracy: 0.8578
# Epoch 75/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3450 - accuracy: 0.8568
# Epoch 76/100
# 7200/7200 [==============================] - 1s 134us/sample - loss: 0.3444 - accuracy: 0.8585
# Epoch 77/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.3441 - accuracy: 0.8607
# Epoch 78/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3440 - accuracy: 0.8583
# Epoch 79/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.3435 - accuracy: 0.8582
# Epoch 80/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.3433 - accuracy: 0.8589
# Epoch 81/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.3429 - accuracy: 0.8585
# Epoch 82/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.3435 - accuracy: 0.8589
# Epoch 83/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.3437 - accuracy: 0.8581
# Epoch 84/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3424 - accuracy: 0.8600
# Epoch 85/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.3427 - accuracy: 0.8597 - loss: 0.3318 - ac
# Epoch 86/100
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.3427 - accuracy: 0.8585 - loss:
# Epoch 87/100
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.3420 - accuracy: 0.8593
# Epoch 88/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3429 - accuracy: 0.8589
# Epoch 89/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3421 - accuracy: 0.8607
# Epoch 90/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.3420 - accuracy: 0.8586
# Epoch 91/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3425 - accuracy: 0.8599
# Epoch 92/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3424 - accuracy: 0.8603 - loss: 0.3429
# Epoch 93/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.3425 - accuracy: 0.8589
# Epoch 94/100
# 7200/7200 [==============================] - 1s 133us/sample - loss: 0.3420 - accuracy: 0.8593
# Epoch 95/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.3425 - accuracy: 0.8610
# Epoch 96/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.3420 - accuracy: 0.8583
# Epoch 97/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.3418 - accuracy: 0.8610
# Epoch 98/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3419 - accuracy: 0.8615
# Epoch 99/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.3415 - accuracy: 0.8606
# Epoch 100/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.3420 - accuracy: 0.8618
# Train on 7200 samples
# Epoch 1/100
# 7200/7200 [==============================] - 2s 287us/sample - loss: 0.5832 - accuracy: 0.7954
# Epoch 2/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.4337 - accuracy: 0.7975
# Epoch 3/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.4267 - accuracy: 0.7975
# Epoch 4/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.4234 - accuracy: 0.7975
# Epoch 5/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.4206 - accuracy: 0.7975
# Epoch 6/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.4184 - accuracy: 0.7975
# Epoch 7/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.4166 - accuracy: 0.7993
# Epoch 8/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.4151 - accuracy: 0.8235
# Epoch 9/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.4139 - accuracy: 0.8267
# Epoch 10/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4127 - accuracy: 0.8286
# Epoch 11/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4118 - accuracy: 0.8296
# Epoch 12/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.4111 - accuracy: 0.8304
# Epoch 13/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.4103 - accuracy: 0.8293
# Epoch 14/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.4095 - accuracy: 0.8317
# Epoch 15/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.4089 - accuracy: 0.8335
# Epoch 16/100
# 7200/7200 [==============================] - 1s 135us/sample - loss: 0.4080 - accuracy: 0.8336
# Epoch 17/100
# 7200/7200 [==============================] - 1s 86us/sample - loss: 0.4077 - accuracy: 0.8338
# Epoch 18/100
# 7200/7200 [==============================] - 0s 69us/sample - loss: 0.4072 - accuracy: 0.8350
# Epoch 19/100
# 7200/7200 [==============================] - 1s 88us/sample - loss: 0.4066 - accuracy: 0.8335
# Epoch 20/100
# 7200/7200 [==============================] - 1s 82us/sample - loss: 0.4061 - accuracy: 0.8360
# Epoch 21/100
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.4058 - accuracy: 0.8350
# Epoch 22/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.4054 - accuracy: 0.8351
# Epoch 23/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.4051 - accuracy: 0.8346
# Epoch 24/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4046 - accuracy: 0.8342
# Epoch 25/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.4041 - accuracy: 0.8333
# Epoch 26/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4037 - accuracy: 0.8356
# Epoch 27/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.4034 - accuracy: 0.8358
# Epoch 28/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.4031 - accuracy: 0.8361
# Epoch 29/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.4028 - accuracy: 0.8356
# Epoch 30/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.4024 - accuracy: 0.8364
# Epoch 31/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.4023 - accuracy: 0.8356
# Epoch 32/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4020 - accuracy: 0.8354
# Epoch 33/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.4020 - accuracy: 0.8356
# Epoch 34/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.4015 - accuracy: 0.8361
# Epoch 35/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.4014 - accuracy: 0.8361
# Epoch 36/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.4011 - accuracy: 0.8363
# Epoch 37/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.4008 - accuracy: 0.8361
# Epoch 38/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.4010 - accuracy: 0.8367
# Epoch 39/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.4007 - accuracy: 0.8356
# Epoch 40/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.4005 - accuracy: 0.8354
# Epoch 41/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.4004 - accuracy: 0.8375
# Epoch 42/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.4001 - accuracy: 0.8368
# Epoch 43/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3998 - accuracy: 0.8344
# Epoch 44/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.4000 - accuracy: 0.8374
# Epoch 45/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3999 - accuracy: 0.8365
# Epoch 46/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3999 - accuracy: 0.8358
# Epoch 47/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3995 - accuracy: 0.8372
# Epoch 48/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3997 - accuracy: 0.8368
# Epoch 49/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.3995 - accuracy: 0.8368
# Epoch 50/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3993 - accuracy: 0.8372
# Epoch 51/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3992 - accuracy: 0.8367
# Epoch 52/100
# 7200/7200 [==============================] - 1s 139us/sample - loss: 0.3991 - accuracy: 0.8360
# Epoch 53/100
# 7200/7200 [==============================] - 1s 134us/sample - loss: 0.3993 - accuracy: 0.8365
# Epoch 54/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.3991 - accuracy: 0.8369
# Epoch 55/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3990 - accuracy: 0.8358
# Epoch 56/100
# 7200/7200 [==============================] - 1s 133us/sample - loss: 0.3992 - accuracy: 0.8368
# Epoch 57/100
# 7200/7200 [==============================] - 1s 135us/sample - loss: 0.3986 - accuracy: 0.8365
# Epoch 58/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3988 - accuracy: 0.8367
# Epoch 59/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.3986 - accuracy: 0.8357
# Epoch 60/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.3989 - accuracy: 0.8365
# Epoch 61/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.3987 - accuracy: 0.8363
# Epoch 62/100
# 7200/7200 [==============================] - 1s 133us/sample - loss: 0.3986 - accuracy: 0.8365
# Epoch 63/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3986 - accuracy: 0.8364
# Epoch 64/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.3983 - accuracy: 0.8375
# Epoch 65/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.3986 - accuracy: 0.8360
# Epoch 66/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.3985 - accuracy: 0.8361
# Epoch 67/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.3983 - accuracy: 0.8358
# Epoch 68/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3984 - accuracy: 0.8369
# Epoch 69/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3984 - accuracy: 0.8364
# Epoch 70/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.3982 - accuracy: 0.8344
# Epoch 71/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.3984 - accuracy: 0.8360
# Epoch 72/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3980 - accuracy: 0.8367
# Epoch 73/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.3981 - accuracy: 0.8368
# Epoch 74/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3982 - accuracy: 0.8360
# Epoch 75/100
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.3980 - accuracy: 0.8367
# Epoch 76/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3984 - accuracy: 0.8351
# Epoch 77/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.3981 - accuracy: 0.8369
# Epoch 78/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3980 - accuracy: 0.8361
# Epoch 79/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3980 - accuracy: 0.8361
# Epoch 80/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.3981 - accuracy: 0.8356
# Epoch 81/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3981 - accuracy: 0.8360
# Epoch 82/100
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.3979 - accuracy: 0.8363
# Epoch 83/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.3980 - accuracy: 0.8363
# Epoch 84/100
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.3978 - accuracy: 0.8357
# Epoch 85/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.3977 - accuracy: 0.8353
# Epoch 86/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.3978 - accuracy: 0.8354
# Epoch 87/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.3976 - accuracy: 0.8361
# Epoch 88/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.3977 - accuracy: 0.8364
# Epoch 89/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3977 - accuracy: 0.8360
# Epoch 90/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.3977 - accuracy: 0.8357
# Epoch 91/100
# 7200/7200 [==============================] - 1s 140us/sample - loss: 0.3975 - accuracy: 0.8375
# Epoch 92/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3976 - accuracy: 0.8357
# Epoch 93/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.3975 - accuracy: 0.8363
# Epoch 94/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3977 - accuracy: 0.8360
# Epoch 95/100
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.3976 - accuracy: 0.8361
# Epoch 96/100
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.3976 - accuracy: 0.8351
# Epoch 97/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.3975 - accuracy: 0.8363
# Epoch 98/100
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.3974 - accuracy: 0.8361
# Epoch 99/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.3974 - accuracy: 0.8353
# Epoch 100/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.3973 - accuracy: 0.8347
# Train on 7200 samples
# Epoch 1/100
# 7200/7200 [==============================] - 2s 309us/sample - loss: 0.5778 - accuracy: 0.7915
# Epoch 2/100
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.4398 - accuracy: 0.7937
# Epoch 3/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4340 - accuracy: 0.7937
# Epoch 4/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.4314 - accuracy: 0.7937
# Epoch 5/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.4290 - accuracy: 0.7937
# Epoch 6/100
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4266 - accuracy: 0.7937
# Epoch 7/100
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4244 - accuracy: 0.7937
# Epoch 8/100
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.4224 - accuracy: 0.8100
# Epoch 9/100
# 7200/7200 [==============================] - 1s 111us/sample - loss: 0.4208 - accuracy: 0.8190
# Epoch 10/100
# 7200/7200 [==============================] - 1s 115us/sample - loss: 0.4199 - accuracy: 0.8254
# Epoch 11/100
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.4187 - accuracy: 0.8253
# Epoch 12/100
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.4176 - accuracy: 0.8271
# Epoch 13/100
# 7200/7200 [==============================] - 1s 136us/sample - loss: 0.4164 - accuracy: 0.8292
# Epoch 14/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4154 - accuracy: 0.8283
# Epoch 15/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.4146 - accuracy: 0.8311
# Epoch 16/100
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.4135 - accuracy: 0.8310
# Epoch 17/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4130 - accuracy: 0.8315
# Epoch 18/100
# 7200/7200 [==============================] - 1s 135us/sample - loss: 0.4124 - accuracy: 0.8314
# Epoch 19/100
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.4117 - accuracy: 0.8329
# Epoch 20/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.4112 - accuracy: 0.8329
# Epoch 21/100
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.4107 - accuracy: 0.8315
# Epoch 22/100
# 7200/7200 [==============================] - 1s 134us/sample - loss: 0.4105 - accuracy: 0.8324
# Epoch 23/100
# 7200/7200 [==============================] - 1s 140us/sample - loss: 0.4102 - accuracy: 0.8346
# Epoch 24/100
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.4095 - accuracy: 0.8329
# Epoch 25/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.4092 - accuracy: 0.8349
# Epoch 26/100
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.4088 - accuracy: 0.8342
# Epoch 27/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.4083 - accuracy: 0.8342
# Epoch 28/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.4082 - accuracy: 0.8321
# Epoch 29/100
# 7200/7200 [==============================] - 1s 125us/sample - loss: 0.4078 - accuracy: 0.8328
# Epoch 30/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.4076 - accuracy: 0.8335
# Epoch 31/100
# 7200/7200 [==============================] - 1s 111us/sample - loss: 0.4075 - accuracy: 0.8335
# Epoch 32/100
# 7200/7200 [==============================] - 1s 131us/sample - loss: 0.4071 - accuracy: 0.8342
# Epoch 33/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.4069 - accuracy: 0.8332
# Epoch 34/100
# 7200/7200 [==============================] - 1s 133us/sample - loss: 0.4070 - accuracy: 0.8356
# Epoch 35/100
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4066 - accuracy: 0.8331
# Epoch 36/100
# 7200/7200 [==============================] - 1s 136us/sample - loss: 0.4064 - accuracy: 0.8328
# Epoch 37/100
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.4061 - accuracy: 0.8350
# Epoch 38/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.4059 - accuracy: 0.8347
# Epoch 39/100
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.4061 - accuracy: 0.8331
# Epoch 40/100
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.4055 - accuracy: 0.8339
# Epoch 41/100
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.4056 - accuracy: 0.8326
# Epoch 42/100
# 7200/7200 [==============================] - 1s 129us/sample - loss: 0.4055 - accuracy: 0.8333
# Epoch 43/100
# ...
# Epoch 212/500
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.4028 - accuracy: 0.8325
# Epoch 213/500
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.4031 - accuracy: 0.8318
# Epoch 214/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4025 - accuracy: 0.8328
# Epoch 215/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4025 - accuracy: 0.8325
# Epoch 216/500
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4026 - accuracy: 0.8333
# Epoch 217/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4026 - accuracy: 0.8324
# Epoch 218/500
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4026 - accuracy: 0.8321
# Epoch 219/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4022 - accuracy: 0.8322
# Epoch 220/500
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4025 - accuracy: 0.8332
# Epoch 221/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4024 - accuracy: 0.8332
# Epoch 222/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4027 - accuracy: 0.8326
# Epoch 223/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4024 - accuracy: 0.8339
# Epoch 224/500
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.4023 - accuracy: 0.8336 - loss: 0.4093 - accu
# Epoch 225/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4023 - accuracy: 0.8333
# Epoch 226/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4028 - accuracy: 0.8317
# Epoch 227/500
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4026 - accuracy: 0.8325
# Epoch 228/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4023 - accuracy: 0.8328
# Epoch 229/500
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.4024 - accuracy: 0.8335
# Epoch 230/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4024 - accuracy: 0.8331
# Epoch 231/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4023 - accuracy: 0.8340
# Epoch 232/500
# 7200/7200 [==============================] - 1s 115us/sample - loss: 0.4022 - accuracy: 0.8324
# Epoch 233/500
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.4025 - accuracy: 0.8335
# Epoch 234/500
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4020 - accuracy: 0.8325
# Epoch 235/500
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.4023 - accuracy: 0.8318
# Epoch 236/500
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.4022 - accuracy: 0.8342
# Epoch 237/500
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4025 - accuracy: 0.8335
# Epoch 238/500
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.4023 - accuracy: 0.8344
# Epoch 239/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4022 - accuracy: 0.8326
# Epoch 240/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4022 - accuracy: 0.8325
# Epoch 241/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4022 - accuracy: 0.8336
# Epoch 242/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4025 - accuracy: 0.8343
# Epoch 243/500
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.4019 - accuracy: 0.8331
# Epoch 244/500
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4024 - accuracy: 0.8321
# Epoch 245/500
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.4027 - accuracy: 0.8326
# Epoch 246/500
# 7200/7200 [==============================] - 1s 112us/sample - loss: 0.4018 - accuracy: 0.8325
# Epoch 247/500
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4026 - accuracy: 0.8329
# Epoch 248/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4019 - accuracy: 0.8324
# Epoch 249/500
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4024 - accuracy: 0.8356
# Epoch 250/500
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4023 - accuracy: 0.8324
# Epoch 251/500
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4022 - accuracy: 0.8335
# Epoch 252/500
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.4020 - accuracy: 0.8326 - l
# Epoch 253/500
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.4022 - accuracy: 0.8331
# Epoch 254/500
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.4023 - accuracy: 0.8325
# Epoch 255/500
# 7200/7200 [==============================] - 1s 110us/sample - loss: 0.4021 - accuracy: 0.8333
# Epoch 256/500
# 7200/7200 [==============================] - 1s 110us/sample - loss: 0.4021 - accuracy: 0.8329
# Epoch 257/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4023 - accuracy: 0.8324
# Epoch 258/500
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4022 - accuracy: 0.8331
# Epoch 259/500
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4023 - accuracy: 0.8343
# Epoch 260/500
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.4021 - accuracy: 0.8340
# Epoch 261/500
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4026 - accuracy: 0.8329
# Epoch 262/500
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.4018 - accuracy: 0.8338
# Epoch 263/500
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.4024 - accuracy: 0.8343
# Epoch 264/500
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.4019 - accuracy: 0.8333
# Epoch 265/500
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.4022 - accuracy: 0.8319
# Epoch 266/500
# 7200/7200 [==============================] - 1s 111us/sample - loss: 0.4022 - accuracy: 0.8322
# Epoch 267/500
# 7200/7200 [==============================] - 1s 134us/sample - loss: 0.4024 - accuracy: 0.8333
# Epoch 268/500
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4022 - accuracy: 0.8332
# Epoch 269/500
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.4021 - accuracy: 0.8332
# Epoch 270/500
# 7200/7200 [==============================] - 1s 110us/sample - loss: 0.4021 - accuracy: 0.8329
# Epoch 271/500
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.4021 - accuracy: 0.8328
# Epoch 272/500
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.4017 - accuracy: 0.8342
# Epoch 273/500
# 7200/7200 [==============================] - 1s 106us/sample - loss: 0.4024 - accuracy: 0.8333
# Epoch 274/500
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.4025 - accuracy: 0.8338
# Epoch 275/500
# 7200/7200 [==============================] - 1s 110us/sample - loss: 0.4022 - accuracy: 0.8346
# Epoch 276/500
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.4023 - accuracy: 0.8331
# Epoch 277/500
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.4020 - accuracy: 0.8338
# Epoch 278/500
# 3825/7200 [==============>...............] - ETA: 0s - loss: 0.3962 - accuracy: 0.8350
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-ceca2b005753> in <module>
#      39                            scoring = 'accuracy',
#      40                            cv = 10)
# ---> 41 grid_search = grid_search.fit(X_train, y_train)
#      42 best_parameters = grid_search.best_params_
#      43 best_accuracy = grid_search.best_score_
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\tensorflow_core\python\keras\wrappers\scikit_learn.py in fit(self, x, y, **kwargs)
#     221       raise ValueError('Invalid shape for y: ' + str(y.shape))
#     222     self.n_classes_ = len(self.classes_)
# --> 223     return super(KerasClassifier, self).fit(x, y, **kwargs)
#     224
#     225   def predict(self, x, **kwargs):
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\tensorflow_core\python\keras\wrappers\scikit_learn.py in fit(self, x, y, **kwargs)
#     164     fit_args.update(kwargs)
#     165
# --> 166     history = self.model.fit(x, y, **fit_args)
#     167
#     168     return history
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     119       current_batch_size = num_samples - step * batch_size
#     120     with training_context.on_batch(
# --> 121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
#     123         batch_outs = execution_function(iterator)
#
# C:\Anaconda3\envs\PythonCPU\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_batch(self, step, mode, size)
#     691     batch_logs = {'batch': step, 'size': size}
#     692     self.callbacks._call_batch_hook(
# --> 693         mode, 'begin', step, batch_logs)
#     694     self.progbar.on_batch_begin(step, batch_logs)
#     695     try:
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     236     self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#     237
# --> 238     delta_t_median = np.median(self._delta_ts[hook_name])
#     239     if (self._delta_t_batch > 0. and
#     240         delta_t_median > 0.95 * self._delta_t_batch and delta_t_median > 0.1):
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\numpy\lib\function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3493     """
#    3494     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3495                     overwrite_input=overwrite_input)
#    3496     if keepdims:
#    3497         return r.reshape(k)
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3401         keepdim = (1,) * a.ndim
#    3402
# -> 3403     r = func(a, **kwargs)
#    3404     return r, keepdim
#    3405
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\numpy\lib\function_base.py in _median(a, axis, out, overwrite_input)
#    3526             part = a
#    3527     else:
# -> 3528         part = partition(a, kth, axis=axis)
#    3529
#    3530     if part.shape == ():
#
# <__array_function__ internals> in partition(*args, **kwargs)
#
# C:\Anaconda3\envs\PythonCPU\lib\site-packages\numpy\core\fromnumeric.py in partition(a, kth, axis, kind, order)
#     744     else:
#     745         a = asanyarray(a).copy(order="K")
# --> 746     a.partition(kth, axis=axis, kind=kind, order=order)
#     747     return a
#     748
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    classifier.add(Dropout(rate = 0.1))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dropout(rate = 0.1))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dropout(rate = 0.1))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier)
parameters = {'batch_size': [25, 32],
              'nb_epoch': [100, 500],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10)
grid_search = grid_search.fit(X_train, y_train)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
# Out:
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 115us/sample - loss: 0.5508 - accuracy: 0.7968
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 102us/sample - loss: 0.5475 - accuracy: 0.7962
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.5811 - accuracy: 0.7943
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 138us/sample - loss: 0.5417 - accuracy: 0.7974
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.5586 - accuracy: 0.7937
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 135us/sample - loss: 0.5582 - accuracy: 0.7931
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 122us/sample - loss: 0.5486 - accuracy: 0.7968
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 134us/sample - loss: 0.6572 - accuracy: 0.7933
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.5655 - accuracy: 0.7957
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.5419 - accuracy: 0.7962
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 141us/sample - loss: 0.5873 - accuracy: 0.7968
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.5754 - accuracy: 0.7953
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 144us/sample - loss: 0.5879 - accuracy: 0.7925
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 121us/sample - loss: 0.6065 - accuracy: 0.7957
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.5995 - accuracy: 0.7928
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 152us/sample - loss: 0.5805 - accuracy: 0.7929
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.5900 - accuracy: 0.7961
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.5998 - accuracy: 0.7953
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 117us/sample - loss: 0.5643 - accuracy: 0.7943
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.5913 - accuracy: 0.7949
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 130us/sample - loss: 0.5791 - accuracy: 0.7960
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.5656 - accuracy: 0.7967
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.5496 - accuracy: 0.7953
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.5482 - accuracy: 0.7972
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.5623 - accuracy: 0.7932
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.5713 - accuracy: 0.7919
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 104us/sample - loss: 0.5483 - accuracy: 0.7968
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 150us/sample - loss: 0.5629 - accuracy: 0.7957
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.5417 - accuracy: 0.7957
# Train on 7200 samples
# 7200/7200 [==============================] - ETA: 0s - loss: 0.5946 - accuracy: 0.79 - 1s 104us/sample - loss: 0.5800 - accuracy: 0.7940
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 150us/sample - loss: 0.5753 - accuracy: 0.7964
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 118us/sample - loss: 0.5820 - accuracy: 0.7965
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.6305 - accuracy: 0.7931
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 135us/sample - loss: 0.5611 - accuracy: 0.7971
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 124us/sample - loss: 0.5754 - accuracy: 0.7933
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 120us/sample - loss: 0.6216 - accuracy: 0.7924
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 119us/sample - loss: 0.5916 - accuracy: 0.7956
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 195us/sample - loss: 0.5788 - accuracy: 0.7962
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 141us/sample - loss: 0.5628 - accuracy: 0.7957
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.6144 - accuracy: 0.7944
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 100us/sample - loss: 0.5693 - accuracy: 0.7971
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 141us/sample - loss: 0.5820 - accuracy: 0.7951
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 135us/sample - loss: 0.5961 - accuracy: 0.7946
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 105us/sample - loss: 0.5870 - accuracy: 0.7971
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 127us/sample - loss: 0.5722 - accuracy: 0.7935
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 152us/sample - loss: 0.5754 - accuracy: 0.7944
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 103us/sample - loss: 0.5752 - accuracy: 0.7969
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 99us/sample - loss: 0.5778 - accuracy: 0.7961
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 100us/sample - loss: 0.5747 - accuracy: 0.7951
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 138us/sample - loss: 0.6227 - accuracy: 0.7947
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 114us/sample - loss: 0.6244 - accuracy: 0.7937
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 110us/sample - loss: 0.6134 - accuracy: 0.7940
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 115us/sample - loss: 0.6091 - accuracy: 0.7924
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 160us/sample - loss: 0.6275 - accuracy: 0.7957
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.6119 - accuracy: 0.7931
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.5987 - accuracy: 0.7939
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 116us/sample - loss: 0.5878 - accuracy: 0.7964
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 149us/sample - loss: 0.6232 - accuracy: 0.7946
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.6077 - accuracy: 0.7933
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 107us/sample - loss: 0.6102 - accuracy: 0.7961
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 100us/sample - loss: 0.5775 - accuracy: 0.7965
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 92us/sample - loss: 0.6119 - accuracy: 0.7943
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 136us/sample - loss: 0.6316 - accuracy: 0.7929
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 93us/sample - loss: 0.5934 - accuracy: 0.7944
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 94us/sample - loss: 0.5809 - accuracy: 0.7918
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 94us/sample - loss: 0.5923 - accuracy: 0.7943
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 95us/sample - loss: 0.5753 - accuracy: 0.7964
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 93us/sample - loss: 0.5836 - accuracy: 0.7961
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 96us/sample - loss: 0.5892 - accuracy: 0.7943
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 96us/sample - loss: 0.5804 - accuracy: 0.7956
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 108us/sample - loss: 0.6280 - accuracy: 0.7950
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 109us/sample - loss: 0.6050 - accuracy: 0.7962
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 123us/sample - loss: 0.6134 - accuracy: 0.7943
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 126us/sample - loss: 0.5998 - accuracy: 0.7947
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 139us/sample - loss: 0.6248 - accuracy: 0.7928
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 133us/sample - loss: 0.6093 - accuracy: 0.7936
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 132us/sample - loss: 0.5871 - accuracy: 0.7969
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 194us/sample - loss: 0.5804 - accuracy: 0.7962
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 128us/sample - loss: 0.5975 - accuracy: 0.7947
# Train on 7200 samples
# 7200/7200 [==============================] - 1s 113us/sample - loss: 0.6217 - accuracy: 0.7949
# Train on 8000 samples
# 8000/8000 [==============================] - 1s 99us/sample - loss: 0.6018 - accuracy: 0.7941

# %%
best_accuracy
# Out:
# 0.796
